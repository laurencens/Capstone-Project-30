# %%
import pandas as pd
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn import svm

# Packages for visuals
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.2)

# %%
df = pd.read_csv('instagrampost-labeling.csv')
df = df.drop(labels="Unnamed: 0", axis=1)
df = df.dropna()
df
# Out:
#                                                Steming    Label
# 0    ugm metaverse minecraft challenge hai sobat mi...  Positif
# 1    looking at the challenge or trouble not sure l...  Negatif
# 2    hello sobat online kenal fatmawati universitas...  Positif
# 3    msib mari ajar holaaa everyone tesalonika univ...  Positif
# 4    halo generasi muda indonesia kenal himmatuz za...  Positif
# ..                                                 ...      ...
# 176  terima kasih sempat program studi independent ...  Positif
# 177  agustus kemerdakaan nkri identik riah raya mer...  Positif
# 178  hai magangers bingung studi independen galau p...  Positif
# 179  mt school parsial agenda upgrading trainer lea...  Positif
# 180  ayo ikut kontes foto agustus kemerdakaan nkri ...  Positif
#
# [181 rows x 2 columns]

# %%
pd.value_counts(df['Label'])
# Out:
# C:\Users\Laurence Nicholas S\AppData\Local\Temp\ipykernel_16212\626637336.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(df['Label'])
# Label
# Positif    165
# Netral      12
# Negatif      4
# Name: count, dtype: int64

# %%
labels = ['Positive','Netral','Negatif']
Category2 = [165,12,4]
plt.bar(labels, Category2, tick_label=labels, width=0.5, color=['coral', 'c','yellow'])
plt.xlabel('Kelas Sentimen')
plt.ylabel('Data')
plt.title('Diagram Bar')
plt.show()

#pie chart
color = ['coral', 'c','yellow']
plt.pie(Category2, labels=labels, colors=color,startangle=90, shadow=True, autopct='%1.2f%%', explode=(0.1, 0, 0))
plt.title('Diagram Pie Chart')
plt.legend()
plt.show()

# %%
# Split into train and test data

train_X, test_X, train_Y, test_Y = model_selection.train_test_split(df['Steming'], df['Label'], test_size = 0.3, random_state = 1)

# %%
# Membuat data frame dari hasil split
df_train70 = pd.DataFrame()
df_train70['Steming'] = train_X
df_train70['Label'] = train_Y

df_test30 = pd.DataFrame()
df_test30['Steming'] = test_X
df_test30['Label'] = test_Y

# %%
#Data frame train hasil pembagian
df_train70
# Out:
#                                                Steming    Label
# 94   hallo dhea fitri anggrainy didik bahasa jepang...   Netral
# 73   hallo kanafika auliya rodiatul janah didik bah...   Netral
# 28   hello im arlianti agil from hayam wuruk perban...  Positif
# 90   hallo dinda zuhairotul didik bahasa inggris st...  Positif
# 138  assalamualaikum warahmatullahi wabarakatuh ken...  Positif
# ..                                                 ...      ...
# 133  hi eka salah mahasiswa jurus akuntansi ikut pr...  Positif
# 137  halo kenal fitri khumaeroh salah serta program...  Positif
# 72   hai sobat jitu terima sertifikat program kampu...  Positif
# 140  hello my name is muhammad zaynurroyhan im an i...  Positif
# 37   assalamualaikum wr wb giat studi independen ma...  Positif
#
# [126 rows x 2 columns]

# %%
#Data Frame test Hasil Pembagian
df_test30
# Out:
#                                                Steming    Label
# 117  assalamualaikum halo jody irawan politeknik ma...  Positif
# 93   hallo samuel parlindungsn matematika universit...  Positif
# 113  hii hormat salah serta studi independen kampus...  Positif
# 162  cuplik video ikut program studi independen kam...   Netral
# 35   hallo hafiz serta studi independen learning tr...  Positif
# 54   halo kenal nama fiky ari wijaya universitas pa...  Positif
# 69   alhamdulillah terimakasih god ive passed my mi...  Positif
# 19   selamat serta lolos msib batch aldo febrian di...  Positif
# 125  senang banget sempat magang studi independen a...  Positif
# 150  halo kenal nama alma mahasiswa universitas air...  Positif
# 107  hai muhammad alifuddin akbar institut teknolog...  Positif
# 108  hallo haries anthony program studi sistem info...  Positif
# 11   hello everyone kenal mahasiswi semester nama a...  Positif
# 84   hallo haris hidayatullah fakultas teknologi in...  Positif
# 4    halo generasi muda indonesia kenal himmatuz za...  Positif
# 112  you finally did it halo lita cerita alam studi...  Positif
# 14   assalamualaikum warahmatullahi wabarakatuh hal...  Positif
# 145  studi independen kampus merdeka pt microsoft i...  Positif
# 29   hi riza dewi agustina universitas internasiona...  Positif
# 99                                        msib journey   Netral
# 168  marvelous journey with microsoft education for...  Positif
# 42   hai teman afina track data analyst and program...  Positif
# 51   hello teman finally graduated from pt maribela...  Positif
# 176  terima kasih sempat program studi independent ...  Positif
# 53   hi everyone sarah lidya universitas hkbp nomme...  Positif
# 40   haloo pradika agung santri ikut giat studi ind...  Positif
# 48   hello im rizka nur aulia from putra bangsa uni...  Positif
# 66   halo shinta naurah prodi didik biologi univers...  Positif
# 97   hallo safir nur sosiologi universitas negeri s...   Netral
# 31   halo tiar imam muarif ikut national onboarding...  Positif
# 16   hallo everyone siti sarah munawaroh mahasiswa ...  Positif
# 95   hallo ahmad jayadi program studi teknologi did...  Negatif
# 56   haloo kenal nama ahmad figo alfarqi mahasiswa ...  Positif
# 160  hallo sobat merdeka rizky syafrullah selesai i...  Positif
# 5    halo intan putri sofyani mahasiswi program stu...  Positif
# 102  hallo johan darma surya sihite didik ekonomi u...  Positif
# 154  hallo kenal ziyan fadilla saporette mahasiswa ...  Positif
# 47                                           mari ajar   Netral
# 85   hallo sobat kampus merdeka faisal program stud...  Positif
# 118  halo semuanyaperkenalanan nama dewi kumaratih ...  Positif
# 147  hi everyone my name is aditya rifqi from autom...  Positif
# 91   hallo lailatun nuriyah jurus didik universitas...  Positif
# 58   hai sahabat vitria gita avidah universitas pgr...  Positif
# 105  hallo imam zuhdi didik laut ikan universitas d...  Positif
# 39   assalamualaikum wrwb risma universitas cokroam...  Positif
# 155  muhammad aldi sofyan program studi teknologi i...  Positif
# 44   sempat syukur studi independen maribelajar mic...  Positif
# 82   alhamdulillah terimakasih god ive passed my mi...  Positif
# 33   studi independen allah ilah manfaat engkau kep...  Positif
# 18                                         kelas siang   Netral
# 59   halo kenal aprilia wulandari trisakti school o...  Positif
# 130  hello my name is josephine gale student from i...  Positif
# 81   hallo rahmat noor fauzi teknik elektro politek...   Netral
# 151  halo nila mahardikawati eka damayanti universi...  Positif
# 12   halo salma dewi nur faridah jurus informatika ...  Positif

# %%
df_test30.to_csv('instagrampost-test30.csv')

# %%
df_train70.to_csv('instagrampost-train70.csv')

# %%
# TF-IDF

from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vect_7030 = TfidfVectorizer()
tfidf_vect_7030.fit(df['Steming'])
train_X_tfidf_7030 = tfidf_vect_7030.transform(df_train70['Steming'])
test_X_tfidf_7030 = tfidf_vect_7030.transform(df_test30['Steming'])

# %%
#melihat hasil pembobotan TF-IDF pada data train
print(train_X_tfidf_7030)
# Out:
#   (0, 2334)	0.11458294626682237
#   (0, 2273)	0.22183135726240133
#   (0, 2099)	0.08008366950168869
#   (0, 1989)	0.11767004504373134
#   (0, 1587)	0.3657042546117472
#   (0, 1495)	0.20362850199699045
#   (0, 1431)	0.16526687632402728
#   (0, 1349)	0.11309163279953914
#   (0, 1238)	0.11846479294370009
#   (0, 1051)	0.3657042546117472
#   (0, 949)	0.09182490744628305
#   (0, 920)	0.10099265460055962
#   (0, 814)	0.1520975417515926
#   (0, 705)	0.3387973238586734
#   (0, 585)	0.2129031962436784
#   (0, 533)	0.17030935099417582
#   (0, 529)	0.3387973238586734
#   (0, 238)	0.27370885073576423
#   (0, 130)	0.3657042546117472
#   (1, 2334)	0.0877112620884115
#   (1, 2273)	0.1698080643777647
#   (1, 2099)	0.06130266286142983
#   (1, 2054)	0.25934348728144835
#   (1, 1989)	0.09007438276854955
#   (1, 1863)	0.27994027704963875
#   :	:
#   (124, 125)	0.27164003024090194
#   (124, 113)	0.055570895794437906
#   (124, 96)	0.1321116119755267
#   (124, 5)	0.16971105975329062
#   (125, 2450)	0.2462373890175351
#   (125, 2403)	0.2462373890175351
#   (125, 2186)	0.2657933061058185
#   (125, 2147)	0.2657933061058185
#   (125, 2099)	0.058204691396160205
#   (125, 1950)	0.2462373890175351
#   (125, 1885)	0.2462373890175351
#   (125, 1518)	0.2657933061058185
#   (125, 1446)	0.2657933061058185
#   (125, 1349)	0.08219482982665079
#   (125, 1327)	0.2736338156618551
#   (125, 1157)	0.2657933061058185
#   (125, 1125)	0.1479968911507895
#   (125, 1023)	0.15238453515859476
#   (125, 949)	0.0667382055998218
#   (125, 920)	0.1468026210807091
#   (125, 830)	0.1479968911507895
#   (125, 768)	0.36758328838631027
#   (125, 483)	0.11895347408344137
#   (125, 194)	0.19325041085409822
#   (125, 181)	0.19893118395551168

# %%
#melihat hasil pembobotan TF-IDF pada data test
print(test_X_tfidf_7030)
# Out:
#   (0, 2463)	0.05727003596862937
#   (0, 2401)	0.07869119295594132
#   (0, 2334)	0.03569882678844954
#   (0, 2331)	0.11393678786006188
#   (0, 2328)	0.10555381385164335
#   (0, 2280)	0.10555381385164335
#   (0, 2273)	0.06911254647542714
#   (0, 2236)	0.06012628838981173
#   (0, 2211)	0.1660806644131347
#   (0, 2196)	0.08456568849515116
#   (0, 2189)	0.05727003596862937
#   (0, 2188)	0.11393678786006188
#   (0, 2168)	0.10555381385164335
#   (0, 2159)	0.06012628838981173
#   (0, 2114)	0.08803596632548885
#   (0, 2099)	0.04990084719006774
#   (0, 2056)	0.09122302512914608
#   (0, 2029)	0.08284005112072754
#   (0, 2003)	0.19921199827512923
#   (0, 1989)	0.03666062614957853
#   (0, 1988)	0.06344136591717965
#   (0, 1971)	0.11393678786006188
#   (0, 1958)	0.06633093818090326
#   (0, 1942)	0.07869119295594132
#   (0, 1893)	0.11393678786006188
#   :	:
#   (54, 1733)	0.0610529148621522
#   (54, 1630)	0.18743360762921002
#   (54, 1534)	0.1334996788761846
#   (54, 1530)	0.14469198033415412
#   (54, 1291)	0.17875218416258395
#   (54, 1068)	0.13114107155191812
#   (54, 967)	0.14807716715946176
#   (54, 953)	0.07040102720201181
#   (54, 949)	0.053833972212756515
#   (54, 830)	0.11938080225829785
#   (54, 815)	0.10088439305021536
#   (54, 743)	0.2130654289993439
#   (54, 673)	0.2144005720057227
#   (54, 571)	0.3744547662286756
#   (54, 528)	0.18743360762921002
#   (54, 490)	0.296508849091908
#   (54, 395)	0.24222040556589813
#   (54, 351)	0.14807716715946176
#   (54, 313)	0.1131426544970677
#   (54, 259)	0.1077679009657819
#   (54, 222)	0.12481825540955853
#   (54, 125)	0.09157713669286999
#   (54, 121)	0.27738946366073547
#   (54, 118)	0.17165894471066684
#   (54, 56)	0.06852571933226664

# %%
print(train_X_tfidf_7030.shape)
print(test_X_tfidf_7030.shape)
# Out:
# (126, 2497)
# (55, 2497)

# %%
# You can use the below syntax to see the vocabulary that it has learned from the corpus
print(tfidf_vect_7030.vocabulary_)
# Out:
# {'ugm': 2317, 'metaverse': 1403, 'minecraft': 1415, 'challenge': 404, 'hai': 810, 'sobat': 2052, 'microsoft': 1405, 'rangka': 1794, 'dies': 535, 'natalis': 1487, 'selenggara': 1958, 'kompetisi': 1156, 'nama': 1481, 'giat': 768, 'ikut': 920, 'siswa': 2035, 'smasederajat': 2049, 'mahasiswa': 1308, 'guru': 799, 'syarat': 2139, 'tentu': 2205, 'gambar': 752, 'slide': 2047, 'iya': 1026, 'daftar': 475, 'karya': 1087, 'bitlyugmmetaverse': 330, 'ayo': 222, 'ajak': 55, 'temantemanmu': 2197, 'raih': 1785, 'hadiah': 807, 'total': 2272, 'rp': 1870, 'tunggu': 2302, 'looking': 1281, 'at': 203, 'the': 2224, 'or': 1564, 'trouble': 2288, 'not': 1524, 'sure': 2127, 'lets': 1253, 'gooo': 783, 'sedia': 1941, 'to': 2257, 'spend': 2074, 'all': 89, 'of': 1541, 'my': 1474, 'gabut': 744, 'day': 493, 'and': 125, 'time': 2250, 'fix': 709, 'this': 2236, 'see': 1942, 'hello': 853, 'online': 1555, 'kenal': 1116, 'fatmawati': 678, 'universitas': 2334, 'negeri': 1495, 'makassar': 1318, 'senang': 1974, 'studiproyek': 2101, 'independen': 949, 'sertifikat': 1989, 'harap': 830, 'ilmu': 924, 'oleh': 1550, 'depan': 511, 'manfaat': 1333, 'aspek': 191, 'kuy': 1197, 'guyskalian': 801, 'you': 2463, 'msib': 1452, 'mari': 1348, 'ajar': 56, 'holaaa': 886, 'everyone': 638, 'tesalonika': 2218, 'sumatera': 2116, 'utara': 2359, 'sempat': 1970, 'program': 1733, 'by': 364, 'kemendikbud': 1111, 'maribelajar': 1349, 'official': 1544, 'partner': 1616, 'pt': 1754, 'jalan': 1033, 'studi': 2099, 'ada': 19, 'webinar': 2406, 'latih': 1228, 'lohhh': 1279, 'waaahhh': 2386, 'keren': 1123, 'banget': 247, 'rangkai': 1795, 'fitur': 708, 'team': 2179, 'asah': 181, 'mampu': 1327, 'kerjasama': 1126, 'rencana': 1827, 'susun': 2132, 'telah': 2191, 'tampil': 2160, 'percaya': 1646, 'dapat': 483, 'excited': 645, 'gabung': 743, 'class': 422, 'are': 165, 'teman': 2196, 'next': 1501, 'year': 2460, 'is': 1015, 'your': 2465, 'turn': 2305, 'adik': 25, 'dkk': 557, 'halo': 815, 'generasi': 764, 'muda': 1457, 'indonesia': 953, 'himmatuz': 878, 'zahiroh': 2480, 'prodi': 1720, 'manajemen': 1331, 'informatika': 967, 'surabaya': 2124, 'kampus': 1079, 'merdeka': 1400, 'batch': 259, 'kembang': 1109, 'potensi': 1689, 'tambah': 2159, 'wawas': 2401, 'bidang': 313, 'data': 490, 'analyst': 121, 'sinar': 2024, 'terang': 2208, 'terus': 2217, 'bangsa': 252, 'lewat': 1256, 'ragu': 1777, 'intan': 993, 'putri': 1769, 'sofyani': 2059, 'mahasiswi': 1310, 'matematika': 1361, 'pamulang': 1596, 'salah': 1886, 'serta': 1987, 'bacth': 232, 'cerdas': 395, 'ambil': 107, 'rangakaian': 1793, 'tahu': 2149, 'analys': 120, 'terima': 2210, 'tawar': 2177, 'sib': 2010, 'lewatin': 1257, 'mandiri': 1332, 'faradia': 672, 'nur': 1530, 'karimah': 1085, 'jurus': 1068, 'sistem': 2034, 'informasi': 964, 'bangun': 253, 'relasi': 1818, 'industri': 959, 'pilih': 1667, 'mitra': 1423, 'bimbing': 318, 'assalamualaikum': 194, 'tarisa': 2170, 'asri': 192, 'rahmayanti': 1784, 'didik': 533, 'ipa': 1010, 'untirta': 2343, 'angkat': 131, 'moga': 1433, 'semangat': 1963, 'minat': 1414, 'guna': 797, 'cipta': 420, 'halhal': 813, 'takjub': 2153, 'lingkup': 1267, 'yukk': 2471, 'alam': 73, 'sangatt': 1898, 'tarik': 2169, 'dna': 559, 'guyss': 802, 'savira': 1916, 'yuliani': 2474, 'teknik': 2185, 'elektro': 597, 'muhammadiyah': 1460, 'surakarta': 2126, 'progam': 1731, 'independent': 950, 'engineer': 609, 'dunia': 571, 'aplikasi': 151, 'life': 1261, 'beautiful': 265, 'struggle': 2096, 'ramadya': 1789, 'wahyu': 2389, 'dwinanto': 575, 'purwokerto': 1765, 'dalam': 478, 'paham': 1590, 'konsep': 1165, 'analisis': 118, 'selesai': 1959, 'sertifikasi': 1988, 'aku': 67, 'memvalidasi': 1383, 'kualifikasi': 1180, 'praktisi': 1702, 'proyekproyek': 1750, 'nyata': 1534, 'libat': 1259, 'terap': 2209, 'ahli': 50, 'emas': 601, 'semester': 1969, 'aulia': 211, 'psikologi': 1751, 'pancasila': 1597, 'jakarta': 1032, 'soft': 2055, 'hard': 831, 'aktivitas': 65, 'kuliah': 1184, 'gali': 751, 'peluang': 1633, 'project': 1738, 'stupen': 2105, 'yukks': 2472, 'go': 776, 'pikir': 1666, 'teknologi': 21 ...

# %%
from sklearn.svm import SVC

#Menerapkan pemodelan SVM pada data train
model = SVC(kernel='linear',
            decision_function_shape='ovr',
           C=1.0)
clf = model.fit(train_X_tfidf_7030,train_Y)

# %%
# Proses Pengujian
predictions_SVM_7030 = clf.predict(test_X_tfidf_7030)

#simpan data frame
test_prediction_7030 = pd.DataFrame()
test_prediction_7030['Text'] = test_X
test_prediction_7030['Label'] = predictions_SVM_7030

test_prediction_7030.to_csv('instagramcom-post_prediction_7030.csv')

from sklearn.metrics import confusion_matrix
#confusion Matrix

class_label = ["Negatif","Netral","Positif"]
df_cm = pd.DataFrame(confusion_matrix(test_Y, predictions_SVM_7030), index=class_label, columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# Accuracy, Precision, Recall, f1-score
from sklearn.metrics import f1_score, precision_score, recall_score,accuracy_score
from sklearn.metrics import classification_report

print (classification_report(test_Y, predictions_SVM_7030))

print("Accuracy of the model : ", accuracy_score(test_Y, predictions_SVM_7030))
print('Precision of the model: ', precision_score(test_Y, predictions_SVM_7030, average='macro'))
print('Recall of the model: ', recall_score(test_Y, predictions_SVM_7030, average='macro'))
print('F1-score of the model: ', f1_score(test_Y, predictions_SVM_7030, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#      Negatif       0.00      0.00      0.00         1
#       Netral       0.00      0.00      0.00         6
#      Positif       0.87      1.00      0.93        48
#
#     accuracy                           0.87        55
#    macro avg       0.29      0.33      0.31        55
# weighted avg       0.76      0.87      0.81        55
#
# Accuracy of the model :  0.8727272727272727
# Precision of the model:  0.2909090909090909
# Recall of the model:  0.3333333333333333
# F1-score of the model:  0.31067961165048547
# c:\Users\Laurence Nicholas S\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Laurence Nicholas S\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Laurence Nicholas S\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Laurence Nicholas S\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB()
clf.fit(train_X_tfidf_7030,train_Y)
predictions= clf.predict(test_X_tfidf_7030)

# %%
from sklearn.metrics import confusion_matrix
#confusion Matrix

class_label = ["Negatif","Netral","Positif"]
df_cm = pd.DataFrame(confusion_matrix(test_Y, predictions), index=class_label, columns=class_label)
sns.heatmap(df_cm, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
# Accuracy, Precision, Recall, f1-score
from sklearn.metrics import f1_score, precision_score, recall_score,accuracy_score
from sklearn.metrics import classification_report


print (classification_report(test_Y, predictions))

print("Accuracy of the model : ", accuracy_score(test_Y, predictions))
print('Precision of the model: ', precision_score(test_Y, predictions, average='macro'))
print('Recall of the model: ', recall_score(test_Y, predictions, average='macro'))
print('F1-score of the model: ', f1_score(test_Y, predictions, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#      Negatif       0.00      0.00      0.00         1
#       Netral       0.00      0.00      0.00         6
#      Positif       0.87      1.00      0.93        48
#
#     accuracy                           0.87        55
#    macro avg       0.29      0.33      0.31        55
# weighted avg       0.76      0.87      0.81        55
#
# Accuracy of the model :  0.8727272727272727
# Precision of the model:  0.2909090909090909
# Recall of the model:  0.3333333333333333
# F1-score of the model:  0.31067961165048547
# c:\Users\Laurence Nicholas S\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Laurence Nicholas S\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Laurence Nicholas S\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Laurence Nicholas S\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
