# %%
import pandas as pd
import re
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Laurence Nicholas
# [nltk_data]     S\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv("allfixdatagabungan.csv", encoding='utf-8')
df
# Out:
#               publishedAt    authorDisplayName  \
# 0    2020-07-01T10:07:34Z        Mama Kasminah
# 1    2020-02-04T07:32:20Z          Eva R. Dewi
# 2    2021-07-29T06:03:26Z   Darrent Alvinno Li
# 3    2016-04-18T04:33:16Z  Raissa Aqila Nalani
# 4    2020-06-16T14:46:53Z           Jendela HR
# ..                    ...                  ...
# 145  2022-11-17T02:20:53Z            Tri Lokon
# 146  2022-11-21T04:11:12Z            Tri Lokon
# 147  2023-03-07T13:13:23Z    Anda Sukanda NIGN
# 148  2020-04-25T10:37:07Z           Tambora 80
# 149  2018-12-06T17:01:35Z       Hackim Luqzman
#
#                              textDisplay  likeCount
# 0                                  Trims          0
# 1    cara nyimpan gamenya gimanaaa??????          0
# 2                             Save world          0
# 3                                  bagus          0
# 4        Subscribe balik ya boss, thanks          0
# ..                                   ...        ...
# 145     Menyimak, kemarin ketinggalan...          0
# 146                          Menyimak ..          0
# 147                        Luar biasa !!          0
# 148                          Terimakasih          0
# 149       password yg dimasukin apa gan?          0
#
# [150 rows x 4 columns]

# %%
df.drop(df.columns[[0,1,3]], axis = 1, inplace = True)
df
# Out:
#                              textDisplay
# 0                                  Trims
# 1    cara nyimpan gamenya gimanaaa??????
# 2                             Save world
# 3                                  bagus
# 4        Subscribe balik ya boss, thanks
# ..                                   ...
# 145     Menyimak, kemarin ketinggalan...
# 146                          Menyimak ..
# 147                        Luar biasa !!
# 148                          Terimakasih
# 149       password yg dimasukin apa gan?
#
# [150 rows x 1 columns]

# %%
#Case Folding
df['CaseFolding'] = df['textDisplay'].str.lower()
df.head()
# Out:
#                            textDisplay                          CaseFolding
# 0                                Trims                                trims
# 1  cara nyimpan gamenya gimanaaa??????  cara nyimpan gamenya gimanaaa??????
# 2                           Save world                           save world
# 3                                bagus                                bagus
# 4      Subscribe balik ya boss, thanks      subscribe balik ya boss, thanks

# %%
# ------ CleanData ---------

def cleaning(text):

    #menghapus username 
    text = re.sub('@[^\s]+','',text)

    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')

    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

    #remove number
    text = re.sub(r"\d+", "", text)

    #remove punctuation
    text = text.translate(str.maketrans("","",string.punctuation))

    # remove white space
    text = text.strip()

    #remove multiple white space
    text = re.sub('\s+',' ',text)

    #remove single char
    text = re.sub(r"\b[a-zA-Z]\b", "", text)

    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")


df['TextClean'] = df['CaseFolding'].apply(cleaning)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\w'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\w'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Laurence Nicholas S\AppData\Local\Temp\ipykernel_19692\275127793.py:6: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('@[^\s]+','',text)
# C:\Users\Laurence Nicholas S\AppData\Local\Temp\ipykernel_19692\275127793.py:15: SyntaxWarning: invalid escape sequence '\w'
#   text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
# C:\Users\Laurence Nicholas S\AppData\Local\Temp\ipykernel_19692\275127793.py:27: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+',' ',text)

# %%
df
# Out:
#                              textDisplay                          CaseFolding  \
# 0                                  Trims                                trims
# 1    cara nyimpan gamenya gimanaaa??????  cara nyimpan gamenya gimanaaa??????
# 2                             Save world                           save world
# 3                                  bagus                                bagus
# 4        Subscribe balik ya boss, thanks      subscribe balik ya boss, thanks
# ..                                   ...                                  ...
# 145     Menyimak, kemarin ketinggalan...     menyimak, kemarin ketinggalan...
# 146                          Menyimak ..                          menyimak ..
# 147                        Luar biasa !!                        luar biasa !!
# 148                          Terimakasih                          terimakasih
# 149       password yg dimasukin apa gan?       password yg dimasukin apa gan?
#
#                           TextClean
# 0                             trims
# 1     cara nyimpan gamenya gimanaaa
# 2                        save world
# 3                             bagus
# 4    subscribe balik ya boss thanks
# ..                              ...
# 145    menyimak kemarin ketinggalan
# 146                        menyimak
# 147                      luar biasa
# 148                     terimakasih
# 149   password yg dimasukin apa gan
#
# [150 rows x 3 columns]

# %%
# Tokenzing
# NLTK word rokenize
def word_tokenize_wrapper(text):
    return word_tokenize(text)
df['Tokenizing'] =df['TextClean'].apply(word_tokenize_wrapper)
df
# Out:
#                              textDisplay                          CaseFolding  \
# 0                                  Trims                                trims
# 1    cara nyimpan gamenya gimanaaa??????  cara nyimpan gamenya gimanaaa??????
# 2                             Save world                           save world
# 3                                  bagus                                bagus
# 4        Subscribe balik ya boss, thanks      subscribe balik ya boss, thanks
# ..                                   ...                                  ...
# 145     Menyimak, kemarin ketinggalan...     menyimak, kemarin ketinggalan...
# 146                          Menyimak ..                          menyimak ..
# 147                        Luar biasa !!                        luar biasa !!
# 148                          Terimakasih                          terimakasih
# 149       password yg dimasukin apa gan?       password yg dimasukin apa gan?
#
#                           TextClean                            Tokenizing
# 0                             trims                               [trims]
# 1     cara nyimpan gamenya gimanaaa    [cara, nyimpan, gamenya, gimanaaa]
# 2                        save world                         [save, world]
# 3                             bagus                               [bagus]
# 4    subscribe balik ya boss thanks  [subscribe, balik, ya, boss, thanks]
# ..                              ...                                   ...
# 145    menyimak kemarin ketinggalan      [menyimak, kemarin, ketinggalan]
# 146                        menyimak                            [menyimak]
# 147                      luar biasa                         [luar, biasa]
# 148                     terimakasih                         [terimakasih]
# 149   password yg dimasukin apa gan   [password, yg, dimasukin, apa, gan]
#
# [150 rows x 4 columns]

# %%
#normalisasi

normalizad_word = pd.read_excel("normalisasi.xlsx")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df['Normalization'] = df['Tokenizing'].apply(normalized_term)

df
# Out:
# C:\Users\Laurence Nicholas S\AppData\Local\Temp\ipykernel_19692\1273413266.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalizad_word_dict:
# C:\Users\Laurence Nicholas S\AppData\Local\Temp\ipykernel_19692\1273413266.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalizad_word_dict[row[0]] = row[1]
#                              textDisplay                          CaseFolding  \
# 0                                  Trims                                trims
# 1    cara nyimpan gamenya gimanaaa??????  cara nyimpan gamenya gimanaaa??????
# 2                             Save world                           save world
# 3                                  bagus                                bagus
# 4        Subscribe balik ya boss, thanks      subscribe balik ya boss, thanks
# ..                                   ...                                  ...
# 145     Menyimak, kemarin ketinggalan...     menyimak, kemarin ketinggalan...
# 146                          Menyimak ..                          menyimak ..
# 147                        Luar biasa !!                        luar biasa !!
# 148                          Terimakasih                          terimakasih
# 149       password yg dimasukin apa gan?       password yg dimasukin apa gan?
#
#                           TextClean                            Tokenizing  \
# 0                             trims                               [trims]
# 1     cara nyimpan gamenya gimanaaa    [cara, nyimpan, gamenya, gimanaaa]
# 2                        save world                         [save, world]
# 3                             bagus                               [bagus]
# 4    subscribe balik ya boss thanks  [subscribe, balik, ya, boss, thanks]
# ..                              ...                                   ...
# 145    menyimak kemarin ketinggalan      [menyimak, kemarin, ketinggalan]
# 146                        menyimak                            [menyimak]
# 147                      luar biasa                         [luar, biasa]
# 148                     terimakasih                         [terimakasih]
# 149   password yg dimasukin apa gan   [password, yg, dimasukin, apa, gan]
#
#                                  Normalization
# 0                                [terimakasih]
# 1             [cara, nyimpan, gamenya, gimana]
# 2                                [save, world]
# 3                                      [bagus]
# 4    [subscribe, balik, ya, boss, terimakasih]
# ..                                         ...
# 145           [menyimak, kemarin, ketinggalan]
# 146                                 [menyimak]
# 147                              [luar, biasa]
# 148                              [terimakasih]
# 149      [password, yang, dimasukin, apa, gan]
#
# [150 rows x 5 columns]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Laurence
# [nltk_data]     Nicholas S\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("stopwords-id.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['Stopwords'] = df['Normalization'].apply(stopwords_removal)


print(df['Stopwords'].head())
# Out:
# 0                     [terimakasih]
# 1        [nyimpan, gamenya, gimana]
# 2                     [save, world]
# 3                           [bagus]
# 4    [subscribe, boss, terimakasih]
# Name: Stopwords, dtype: object

# %%
df
# Out:
#                              textDisplay                          CaseFolding  \
# 0                                  Trims                                trims
# 1    cara nyimpan gamenya gimanaaa??????  cara nyimpan gamenya gimanaaa??????
# 2                             Save world                           save world
# 3                                  bagus                                bagus
# 4        Subscribe balik ya boss, thanks      subscribe balik ya boss, thanks
# ..                                   ...                                  ...
# 145     Menyimak, kemarin ketinggalan...     menyimak, kemarin ketinggalan...
# 146                          Menyimak ..                          menyimak ..
# 147                        Luar biasa !!                        luar biasa !!
# 148                          Terimakasih                          terimakasih
# 149       password yg dimasukin apa gan?       password yg dimasukin apa gan?
#
#                           TextClean                            Tokenizing  \
# 0                             trims                               [trims]
# 1     cara nyimpan gamenya gimanaaa    [cara, nyimpan, gamenya, gimanaaa]
# 2                        save world                         [save, world]
# 3                             bagus                               [bagus]
# 4    subscribe balik ya boss thanks  [subscribe, balik, ya, boss, thanks]
# ..                              ...                                   ...
# 145    menyimak kemarin ketinggalan      [menyimak, kemarin, ketinggalan]
# 146                        menyimak                            [menyimak]
# 147                      luar biasa                         [luar, biasa]
# 148                     terimakasih                         [terimakasih]
# 149   password yg dimasukin apa gan   [password, yg, dimasukin, apa, gan]
#
#                                  Normalization  \
# 0                                [terimakasih]
# 1             [cara, nyimpan, gamenya, gimana]
# 2                                [save, world]
# 3                                      [bagus]
# 4    [subscribe, balik, ya, boss, terimakasih]
# ..                                         ...
# 145           [menyimak, kemarin, ketinggalan]
# 146                                 [menyimak]
# 147                              [luar, biasa]
# 148                              [terimakasih]
# 149      [password, yang, dimasukin, apa, gan]
#
#                             Stopwords
# 0                       [terimakasih]
# 1          [nyimpan, gamenya, gimana]
# 2                       [save, world]
# 3                             [bagus]
# 4      [subscribe, boss, terimakasih]
# ..                                ...
# 145  [menyimak, kemarin, ketinggalan]
# 146                        [menyimak]
# 147                                []
# 148                     [terimakasih]
# 149        [password, dimasukin, gan]
#
# [150 rows x 6 columns]

# %%
df.to_csv('maribelajar-stopwords.csv')

# %%
pip install sastrawi
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ---------------------------------------- 0.0/209.7 kB ? eta -:--:--
#      - -------------------------------------- 10.2/209.7 kB ? eta -:--:--
#      ----- ------------------------------- 30.7/209.7 kB 325.1 kB/s eta 0:00:01
#      ---------- -------------------------- 61.4/209.7 kB 544.7 kB/s eta 0:00:01
#      -------------------------------------  204.8/209.7 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------  204.8/209.7 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 209.7/209.7 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

def steming(text):
    text = stemmer.stem(text)
    return text

# %%
df1 = pd.read_csv('maribelajar-stopwords.csv')
df1
# Out:
#      Unnamed: 0                          textDisplay  \
# 0             0                                Trims
# 1             1  cara nyimpan gamenya gimanaaa??????
# 2             2                           Save world
# 3             3                                bagus
# 4             4      Subscribe balik ya boss, thanks
# ..          ...                                  ...
# 145         145     Menyimak, kemarin ketinggalan...
# 146         146                          Menyimak ..
# 147         147                        Luar biasa !!
# 148         148                          Terimakasih
# 149         149       password yg dimasukin apa gan?
#
#                              CaseFolding                       TextClean  \
# 0                                  trims                           trims
# 1    cara nyimpan gamenya gimanaaa??????   cara nyimpan gamenya gimanaaa
# 2                             save world                      save world
# 3                                  bagus                           bagus
# 4        subscribe balik ya boss, thanks  subscribe balik ya boss thanks
# ..                                   ...                             ...
# 145     menyimak, kemarin ketinggalan...    menyimak kemarin ketinggalan
# 146                          menyimak ..                        menyimak
# 147                        luar biasa !!                      luar biasa
# 148                          terimakasih                     terimakasih
# 149       password yg dimasukin apa gan?   password yg dimasukin apa gan
#
#                                          Tokenizing  \
# 0                                         ['trims']
# 1        ['cara', 'nyimpan', 'gamenya', 'gimanaaa']
# 2                                 ['save', 'world']
# 3                                         ['bagus']
# 4    ['subscribe', 'balik', 'ya', 'boss', 'thanks']
# ..                                              ...
# 145          ['menyimak', 'kemarin', 'ketinggalan']
# 146                                    ['menyimak']
# 147                               ['luar', 'biasa']
# 148                                 ['terimakasih']
# 149   ['password', 'yg', 'dimasukin', 'apa', 'gan']
#
#                                          Normalization  \
# 0                                      ['terimakasih']
# 1             ['cara', 'nyimpan', 'gamenya', 'gimana']
# 2                                    ['save', 'world']
# 3                                            ['bagus']
# 4    ['subscribe', 'balik', 'ya', 'boss', 'terimaka...
# ..                                                 ...
# 145             ['menyimak', 'kemarin', 'ketinggalan']
# 146                                       ['menyimak']
# 147                                  ['luar', 'biasa']
# 148                                    ['terimakasih']
# 149    ['password', 'yang', 'dimasukin', 'apa', 'gan']
#
#                                   Stopwords
# 0                           ['terimakasih']
# 1          ['nyimpan', 'gamenya', 'gimana']
# 2                         ['save', 'world']
# 3                                 ['bagus']
# 4      ['subscribe', 'boss', 'terimakasih']
# ..                                      ...
# 145  ['menyimak', 'kemarin', 'ketinggalan']
# 146                            ['menyimak']
# 147                                      []
# 148                         ['terimakasih']
# 149        ['password', 'dimasukin', 'gan']
#
# [150 rows x 7 columns]

# %%
df1['Steming'] = df1['Stopwords'].apply(steming)
df1.head()
# Out:
#    Unnamed: 0                          textDisplay  \
# 0           0                                Trims
# 1           1  cara nyimpan gamenya gimanaaa??????
# 2           2                           Save world
# 3           3                                bagus
# 4           4      Subscribe balik ya boss, thanks
#
#                            CaseFolding                       TextClean  \
# 0                                trims                           trims
# 1  cara nyimpan gamenya gimanaaa??????   cara nyimpan gamenya gimanaaa
# 2                           save world                      save world
# 3                                bagus                           bagus
# 4      subscribe balik ya boss, thanks  subscribe balik ya boss thanks
#
#                                        Tokenizing  \
# 0                                       ['trims']
# 1      ['cara', 'nyimpan', 'gamenya', 'gimanaaa']
# 2                               ['save', 'world']
# 3                                       ['bagus']
# 4  ['subscribe', 'balik', 'ya', 'boss', 'thanks']
#
#                                        Normalization  \
# 0                                    ['terimakasih']
# 1           ['cara', 'nyimpan', 'gamenya', 'gimana']
# 2                                  ['save', 'world']
# 3                                          ['bagus']
# 4  ['subscribe', 'balik', 'ya', 'boss', 'terimaka...
#
#                               Stopwords                     Steming
# 0                       ['terimakasih']                 terimakasih
# 1      ['nyimpan', 'gamenya', 'gimana']      nyimpan gamenya gimana
# 2                     ['save', 'world']                  save world
# 3                             ['bagus']                       bagus
# 4  ['subscribe', 'boss', 'terimakasih']  subscribe boss terimakasih

# %%
keep_col = ['Steming']
df1 = df1[keep_col]
df1.to_csv('maribelajar-steming.csv')
